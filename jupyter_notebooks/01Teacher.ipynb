# %% [markdown]
# # Example Script of the General Teacher
#
# This is an example script of the General Teacher. For the action search, one only has to execute the `general_teacher
#  ()` method.  Note that this might take some time, depending on your resources

# %%
import os
import grid2op
from pathlib import Path
import logging
from lightsim2grid import LightSimBackend

example_path = os.getcwd()

# %% [markdown]
# First, check whether the Grid2Op Environment can be loaded and executed

# %%
backend = LightSimBackend()
env = grid2op.make("l2rpn_case14_sandbox", backend=backend)
obs = env.get_obs()
# Out:
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)

# %%
from curriculumagent.teacher.teacher import general_teacher

# %% [markdown]
# After importing the module, we run the General Teacher Search. Again note, that this might take a while. If you have a
# limited amount of CPU power, you can reduce the number of jobs accordingly

# %%
# Initialize values:
logging.basicConfig(level=logging.INFO)
path_of_file = Path(example_path) / "data"
path_of_env = "l2rpn_case14_sandbox"
general_teacher(save_path=path_of_file,
                  env_name_path=path_of_env)
# Out:
# INFO:pandapower.convert_format:These dtypes could not be corrected: {'trafo': ['tap_min', 'tap_max']}
# WARNING:pandapower.auxiliary:numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# WARNING:pandapower.auxiliary:numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# WARNING:pandapower.auxiliary:numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# INFO:root:The following 100 tasks will be distributed to a pool of 8 workers: [(WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 42, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 43, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 44, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 45, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 46, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 47, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 48, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 49, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 50, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 51, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 52, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 53, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 54, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 55, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 56, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 57, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 58, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_case14_sandbox', 'C:\\Users\\ddegtyar\\data_grid2op\\l2rpn_case14_sandbox\\chronics', 59, 0.925, 125, None), (WindowsPath('C:/Users/ddegtyar/PycharmProjects/curriculumagent/jupyter_notebooks/experience'), 'l2rpn_ca ...

# %% [markdown]
# After Running the Action Search, it is necessary to collect the experience for the tutor.

# %%
from curriculumagent.teacher.collect_teacher_experience import make_unitary_actionspace
# Out:
# C:\Users\ddegtyar\Anaconda3\envs\currenv\lib\site-packages\lightsim2grid\securityAnalysis.py:76: FutureWarning: In the future `np.str` will be defined as the corresponding NumPy scalar.
#   STR_TYPES = (str, np.str, np.str_)

# %%
path_of_experience = Path(example_path) / "data"
path_of_env = "l2rpn_case14_sandbox"
#list_of_experience = [name for name in os.listdir(path_of_experience) if ".csv" in name]
experience_file = Path(path_of_experience)/ "teacher_experience.csv"

make_unitary_actionspace(action_space_file_path=Path(example_path) / "data" / "example_teacher_actionspace.npy",
                         experience_csv_files=[experience_file],
                         env_name_path=path_of_env,
                         best_n=250)
# Out:
# WARNING:pandapower.auxiliary:numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# WARNING:pandapower.auxiliary:numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# WARNING:pandapower.auxiliary:numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
